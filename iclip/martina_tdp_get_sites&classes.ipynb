# %%
import pybedtools as pbt
import pandas as pd
import seaborn as sns
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
def merge_peaks(peaks, n):
    return peaks.sort().merge(d=n, s=True, c=[4, 5, 6], o=['distinct', 'sum', 'distinct'])

# %%
set1_2_merged30_150motifs = pbt.BedTool('/home/aram/Dropbox (The Francis Crick)/ucl/aram/martina_tdp43/binding_sites_set_1and2/genome_larger_motif_groups/set1_2_merged30_150motifs.bed')

# %%
intersect_merged30_all = set1_2_merged30_150motifs.intersect(pbt.BedTool(
    '/home/aram/data/martina_tdp/thresholded_xl_p05/all_sites_merged_sets_1_2.bed.gz'), 
        s=True,
        wb=True,
        nonamecheck=True)

# %%
df_intersect_merged30_all = intersect_merged30_all.to_dataframe()

# %%
df_out_all = pd.DataFrame()
df_out_all['chrome'] = df_intersect_merged30_all.chrom
df_out_all['start'] = df_intersect_merged30_all.thickEnd
df_out_all['end'] = df_intersect_merged30_all.itemRgb
df_out_all['name'] = df_intersect_merged30_all.name
df_out_all['score'] = df_intersect_merged30_all.blockSizes
df_out_all['strand'] = df_intersect_merged30_all.strand

# %%
df_intersect_merged30_all.head()
# Out:
#         chrom   start     end name  score strand  thickStart  thickEnd  \
# 0  GL000008.2  118900  118901    .     16      -  GL000008.2    118900
# 1  GL000008.2  131468  131469    .     30      +  GL000008.2    131468
# 2  GL000008.2  131470  131471    .     30      +  GL000008.2    131470
# 3  GL000008.2  131471  131472    .     30      +  GL000008.2    131471
# 4  GL000008.2  131472  131473    .     30      +  GL000008.2    131472
#
#    itemRgb blockCount  blockSizes blockStarts
# 0   118901          .           2           -
# 1   131469          .           1           +
# 2   131471          .           6           +
# 3   131472          .           5           +
# 4   131473          .           3           +

# %%
#df_intersect_merged30_all.to_csv('intersect_merged30_all.bed')

# %%
bed_out_all = pbt.BedTool.from_dataframe(df_out_all)

# %%
bed_out_all_unfiltered = merge_peaks(bed_out_all, 30)

# %%
df_all_unfiltered = bed_out_all_unfiltered.to_dataframe()

# %%
files2 = glob.glob('/home/aram/data/martina_tdp/second_big_heatmap/*')

# %%
files1 = glob.glob('/home/aram/data/martina_tdp/test_idr_mutants/*')
files1 = [f for f in files1 if '_peaks' not in f]

# %%
files = files1 + files2

# %%
files
# Out:
# ['/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju_trimmed_single.bed.gz',
#  '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd2-5-3-20180829-ju_trimmed_single.bed.gz',
#  '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju_trimmed_single.bed.gz',
#  '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju_trimmed_single.bed.gz',
#  '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
#  '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju_trimmed_single.bed.gz',
#  '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju_trimmed_single.bed.gz',
#  '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
# ...

# %%
files_old = ['/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd2-5-4-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-a326p-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-g294a-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd1-6-3-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-320del414-egfp-hek293-hd1-6-3-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-no-uv-1-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd1-6-3-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd2-5-4-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-a326p-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-g335a-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-g294a-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-m337p-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-q331k-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd2-5-3-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-g335a-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-316del346-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-q331k-egfp-hek293-3-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-hd1-6-4-20180829-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/test_idr_mutants/tardbp-m337p-egfp-hek293-4-20181001-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-egfp-293flp-m2-20171010-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-316del346-egfp-293flp-l1-20171010-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-316del346-egfp-293flp-l2-20171010-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-egfp-293flp-l2-20171010-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-316del346-egfp-293flp-m1-20171010-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-egfp-293flp-l1-20171010-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-316del346-egfp-293flp-m2-20171010-ju_trimmed_single.bed.gz',
 '/home/aram/data/martina_tdp/second_big_heatmap/tardbp-egfp-293flp-m1-20171010-ju_trimmed_single.bed.gz']

# %%
df_out = df_all_unfiltered.copy()
for file in files_old:
    temp_name = file.split('/')[-1].replace('_trimmed_single.bed.gz', '')
    temp = pbt.BedTool(
        file).intersect(
            bed_out_all_unfiltered,
            s=True,
            wb=True,
            nonamecheck=True)
    df_temp_unmerged = temp.to_dataframe()
    df_temp = pd.DataFrame()
    df_temp['chrome'] = df_temp_unmerged.chrom
    df_temp['start'] = df_temp_unmerged.thickEnd
    df_temp['end'] = df_temp_unmerged.itemRgb
    df_temp['name'] = df_temp_unmerged.name
    df_temp['score'] = df_temp_unmerged.blockSizes
    df_temp['strand'] = df_temp_unmerged.strand
    temp_merged = merge_peaks(pbt.BedTool.from_dataframe(df_temp), 0)
    df_temp_merged = temp_merged.to_dataframe()
    df_temp_merged = df_temp_merged.rename(columns={'score': f'{temp_name}'})
    df_out = pd.merge(df_out, df_temp_merged, on=['chrom', 'start', 'end','name', 'strand'], how='outer')

# %%
df_out.head()
# Out:
#         chrom   start     end name  score strand  \
# 0  GL000008.2  118900  118901    .      2      -
# 1  GL000008.2  131468  131481    .     40      +
# 2  GL000008.2  132030  132032    .      5      +
# 3  GL000008.2  154464  154475    .    113      +
# 4  GL000008.2  155093  155130    .    110      +
#
#    tardbp-316del346-egfp-hek293-4-20181001-ju  \
# 0                                         NaN
# 1                                        40.0
# 2                                         NaN
# 3                                       339.0
# 4                                         NaN
#
#    tardbp-316del346-egfp-hek293-3-20181001-ju  \
# 0                                         NaN
# 1                                         NaN
# 2                                         5.0
# 3                                       113.0
# 4                                       110.0
#
#    tardbp-egfp-hek293-hd2-5-4-20180829-ju  \
# 0                                     NaN
# ...

# %%
df_out_nonan = df_out.fillna(0)

# %%
region_file = '/home/aram/genomes/regions_GENCODE_v30.gtf.gz'

# %%
unfiltered_with_region = pbt.BedTool(
        bed_out_all_unfiltered).intersect(
            region_file,
            s=True,
            wb=True,
            nonamecheck=True)

# %%
df_unfiltered_with_region = unfiltered_with_region.to_dataframe(
    names=['chrom', 'start', 'end', 'name', 'score', 'strand', 'chrom1', 'name1', 'region', 'start1', 'end1', 
          'x1', 'strand1', 'x2', 'info'])

# %%
del df_unfiltered_with_region['chrom1']
del df_unfiltered_with_region['name1']
del df_unfiltered_with_region['start1']
del df_unfiltered_with_region['end1']
del df_unfiltered_with_region['x1']
del df_unfiltered_with_region['strand1']
del df_unfiltered_with_region['x2']

# %%
df_unfiltered_with_region.head()
# Out:
#         chrom   start     end name  score strand      region  \
# 0  GL000008.2  118900  118901    .      2      -  intergenic
# 1  GL000008.2  131468  131481    .     40      +  intergenic
# 2  GL000008.2  132030  132032    .      5      +  intergenic
# 3  GL000008.2  154464  154475    .    113      +  intergenic
# 4  GL000008.2  155093  155130    .    110      +  intergenic
#
#                                        info
# 0  biotype "";gene_id ".";gene_name "None";
# 1  biotype "";gene_id ".";gene_name "None";
# 2  biotype "";gene_id ".";gene_name "None";
# 3  biotype "";gene_id ".";gene_name "None";
# 4  biotype "";gene_id ".";gene_name "None";

# %%
df_unfiltered_with_region['biotype'] = df_unfiltered_with_region['info'].apply(
    lambda x: x.split(';')[0].replace('biotype ', ''))

# %%
df_unfiltered_with_region['gene_id'] = df_unfiltered_with_region['info'].apply(
    lambda x: x.split(';')[1].replace('gene_id ', ''))

# %%
df_unfiltered_with_region['gene_name'] = df_unfiltered_with_region['info'].apply(
    lambda x: x.split(';')[2].replace('gene_name ', ''))

# %%
del df_unfiltered_with_region['info']

# %%
len(df_unfiltered_with_region)
# Out:
# 981033

# %%
df_genes = df_unfiltered_with_region[df_unfiltered_with_region.region != 'intergenic']

# %%
df_genes_100 = df_genes[df_genes.score > 100]

# %%
len(df_genes_100)
# Out:
# 54503

# %%
df_genes['max'] = df_genes.groupby('gene_id')['score'].transform(max)
# Out:
# /home/aram/anaconda3/envs/pandas024/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_genes['ratio'] = df_genes['score'] / df_genes['max']
# Out:
# /home/aram/anaconda3/envs/pandas024/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_genes_filtered = df_genes[df_genes.ratio > 0.1]

# %%
df_genes_filtered = df_genes_filtered[df_genes_filtered.score > 10]

# %%
df_intergenic = df_unfiltered_with_region[df_unfiltered_with_region.region == 'intergenic']
df_intergenic_filtered = df_unfiltered_with_region[df_unfiltered_with_region.score > 100]

# %%
len(df_intergenic), len(df_intergenic_filtered)
# Out:
# (109871, 57022)

# %%
df_genes_filtered.head()
# Out:
#           chrom   start     end name  score strand  region     biotype  \
# 71   GL000194.1   75522   75545    .     22      -  intron  "pre-mRNA"
# 74   GL000194.1   81461   81479    .     13      -  intron  "pre-mRNA"
# 79   GL000194.1   92228   92285    .     68      -  intron  "pre-mRNA"
# 88   GL000194.1   99578   99599    .     23      -  intron  "pre-mRNA"
# 254  KI270442.1  217328  217337    .     19      -   ncRNA      "rRNA"
#
#                  gene_id  gene_name  max     ratio
# 71   "ENSG00000274847.1"    "MAFIP"   68  0.323529
# 74   "ENSG00000274847.1"    "MAFIP"   68  0.191176
# 79   "ENSG00000274847.1"    "MAFIP"   68  1.000000
# 88   "ENSG00000274847.1"    "MAFIP"   68  0.338235
# 254  "ENSG00000278294.1"  "RF00002"   19  1.000000

# %%
del df_genes_filtered['max']
del df_genes_filtered['ratio']
#del df_genes_100['max']
#del df_genes_100['ratio']

# %%
df_genes_filtered = df_genes_filtered.merge(df_genes_100, how='outer', 
    on=['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype', 'gene_id', 'gene_name'])

# %%
df_filtered = pd.concat([df_intergenic_filtered, df_genes_filtered], axis=0, join='outer')

# %%
df_filtered = df_filtered.sort_index()

# %%
df_filtered =  df_filtered.drop_duplicates()

# %%
len(df_filtered)
# Out:
# 120159

# %%
df_filtered.head()
# Out:
#         chrom   start     end name  score strand      region     biotype  \
# 0  GL000194.1   75522   75545    .     22      -      intron  "pre-mRNA"
# 1  GL000194.1   81461   81479    .     13      -      intron  "pre-mRNA"
# 2  GL000194.1   92228   92285    .     68      -      intron  "pre-mRNA"
# 3  GL000194.1   99578   99599    .     23      -      intron  "pre-mRNA"
# 3  GL000008.2  154464  154475    .    113      +  intergenic          ""
#
#                gene_id gene_name
# 0  "ENSG00000274847.1"   "MAFIP"
# 1  "ENSG00000274847.1"   "MAFIP"
# 2  "ENSG00000274847.1"   "MAFIP"
# 3  "ENSG00000274847.1"   "MAFIP"
# 3                  "."    "None"

# %%
rfiltered_merged30 = pbt.BedTool.from_dataframe(
    df_filtered[['chrom', 'start', 'end', 'name', 'score', 'strand']])

# %%
rfiltered_merged30_table = pbt.BedTool(rfiltered_merged30).intersect(
        pbt.BedTool('/home/aram/genomes/regions.bed.gz'),
        s=True,
        wb=True,
        nonamecheck=True)

# %%
df_rfiltered_merged30_table = rfiltered_merged30_table.to_dataframe(
    names=['chrom', 'start', 'end', 'name', 'score', 'strand', 'chrom1', 'name1', 'region', 'start1', 'end1', 
          'x1', 'strand1', 'x2', 'info'])

# %%
del df_rfiltered_merged30_table['chrom1']
del df_rfiltered_merged30_table['name1']
del df_rfiltered_merged30_table['start1']
del df_rfiltered_merged30_table['end1']
del df_rfiltered_merged30_table['x1']
del df_rfiltered_merged30_table['strand1']
del df_rfiltered_merged30_table['x2']

# %%
df_rfiltered_merged30_table['biotype'] = df_rfiltered_merged30_table['info'].apply(
    lambda x: x.split(';')[2].replace('biotype ', ''))
df_rfiltered_merged30_table['gene_id'] = df_rfiltered_merged30_table['info'].apply(
    lambda x: x.split(';')[0].replace('gene_id ', ''))
df_rfiltered_merged30_table['gene_name'] = df_rfiltered_merged30_table['info'].apply(
    lambda x: x.split(';')[1].replace('gene_name ', ''))

# %%
df_rfiltered_merged30_table.head()
# Out:
#         chrom   start     end name  score strand      region  \
# 0  GL000194.1   75522   75545    .     22      -      intron
# 1  GL000194.1   81461   81479    .     13      -      intron
# 2  GL000194.1   92228   92285    .     68      -      intron
# 3  GL000194.1   99578   99599    .     23      -      intron
# 4  GL000008.2  154464  154475    .    113      +  intergenic
#
#                                                 info     biotype  \
# 0  gene_id "ENSG00000274847.1";gene_name "AC14521...  "pre-mRNA"
# 1  gene_id "ENSG00000274847.1";gene_name "AC14521...  "pre-mRNA"
# 2  gene_id "ENSG00000274847.1";gene_name "AC14521...  "pre-mRNA"
# 3  gene_id "ENSG00000274847.1";gene_name "AC14521...  "pre-mRNA"
# 4           gene_id ".";gene_name "None";biotype "";          ""
#
#                gene_id     gene_name
# 0  "ENSG00000274847.1"  "AC145212.1"
# 1  "ENSG00000274847.1"  "AC145212.1"
# 2  "ENSG00000274847.1"  "AC145212.1"
# 3  "ENSG00000274847.1"  "AC145212.1"
# ...

# %%
del df_rfiltered_merged30_table['info']

# %%
df_out_rfiltered_merged30 = df_rfiltered_merged30_table.copy()
for file in files:
    temp_name = file.split('/')[-1].replace('_trimmed_single.bed.gz', '')
    temp = rfiltered_merged30.intersect(
        pbt.BedTool(file),
        s=True,
        wa=True,
        wb=True,
        loj=True,
        nonamecheck=True)
    df_temp_unmerged = temp.to_dataframe()
    df_temp = pd.DataFrame()
    df_temp['chrome'] = df_temp_unmerged.chrom
    df_temp['start'] = df_temp_unmerged.start
    df_temp['end'] = df_temp_unmerged.end
    df_temp['name'] = df_temp_unmerged.name
    df_temp['score'] = df_temp_unmerged.blockSizes
    df_temp['strand'] = df_temp_unmerged.strand
    temp_merged = merge_peaks(pbt.BedTool.from_dataframe(df_temp), 0)
    df_temp_merged = temp_merged.to_dataframe()
    df_temp_merged = df_temp_merged.rename(columns={'score': f'{temp_name}'})
    df_out_rfiltered_merged30 = pd.merge(df_out_rfiltered_merged30, df_temp_merged, on=['chrom', 'start', 'end','name', 'strand'], how='outer')

# %%
df_out_rfiltered_merged30 = df_out_rfiltered_merged30.fillna(0)

# %%
df_out_rfiltered_merged30 = df_out_rfiltered_merged30.replace(-1.0, 0)

# %%
df_out_rfiltered_merged30.head(50)
# Out:
#          chrom    start      end name   score strand      region     biotype  \
# 0   GL000194.1    75522    75545    .    22.0      -      intron  "pre-mRNA"
# 1   GL000194.1    81461    81479    .    13.0      -      intron  "pre-mRNA"
# 2   GL000194.1    92228    92285    .    68.0      -      intron  "pre-mRNA"
# 3   GL000194.1    99578    99599    .    23.0      -      intron  "pre-mRNA"
# 4   GL000008.2   154464   154475    .   113.0      +  intergenic          ""
# 5   GL000008.2   155093   155130    .   110.0      +  intergenic          ""
# 6   KI270442.1   217328   217337    .    19.0      -       ncRNA      "rRNA"
# 7   KI270711.1     8179     8241    .   520.0      -      intron  "pre-mRNA"
# 8   KI270711.1    11269    11343    .   123.0      -      intron  "pre-mRNA"
# 9   KI270713.1    31706    31707    .    12.0      -        UTR3      "mRNA"
# 10  KI270728.1  1140224  1140264    .   157.0      -        UTR3      "mRNA"
# ...

# %%
df_out_rfiltered_merged30.columns
# Out:
# Index(['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
#        'gene_id', 'gene_name',
#        'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-3-20181001-ju',
#        'tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-no-uv-1-20180829-ju',
#        'tardbp-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-a326p-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-q331k-egfp-hek293-3-20181001-ju',
# ...

# %%
len(df_out_rfiltered_merged30)
# Out:
# 122170

# %%
# df_out_rfiltered_merged30[['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
#        'gene_id', 'gene_name']].to_csv('rfiltered_tdp_bs.tsv', sep='\t', index=None)

# %%
df_out_rfiltered_merged30['len'] = df_out_rfiltered_merged30.end - df_out_rfiltered_merged30.start

# %%
group1_raw = pbt.BedTool(
    '/home/aram/Dropbox (The Francis Crick)/ucl/aram/martina_tdp43/binding_sites_set_1and2/genome_larger_motif_groups/set1_2_merged0_TGTGTG_GTGTGT_CGCGCG.bed')
group2_raw = pbt.BedTool(
    '/home/aram/Dropbox (The Francis Crick)/ucl/aram/martina_tdp43/binding_sites_set_1and2/genome_larger_motif_groups/set1_2_merged0_GTGCGC_CGTGTG_TGTGCG.bed')
group3_raw = pbt.BedTool(
    '/home/aram/Dropbox (The Francis Crick)/ucl/aram/martina_tdp43/binding_sites_set_1and2/genome_larger_motif_groups/set1_2_merged0_GTCTGT_TCTGTG_TGTGTC.bed')
group4_raw = pbt.BedTool(
    '/home/aram/Dropbox (The Francis Crick)/ucl/aram/martina_tdp43/binding_sites_set_1and2/genome_larger_motif_groups/set1_2_merged0_ATGTGA_GACTGT_TGTGAT.bed')

# %%
group1 = group1_raw.intersect(rfiltered_merged30, s=True)
group2 = group2_raw.intersect(rfiltered_merged30, s=True)
group3 = group3_raw.intersect(rfiltered_merged30, s=True)
group4 = group4_raw.intersect(rfiltered_merged30, s=True)
# Out:
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# chr1	280750	280772	.	43	-
#
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# chr1	280750	280772	.	43	-
#
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# chr1	280750	280772	.	43	-
#
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# chr1	280750	280772	.	43	-
#
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# chr1	280750	280772	.	43	-
#
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# chr1	280750	280772	.	43	-
#
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# chr1	280750	280772	.	43	-
#
# ***** WARNING: File /tmp/pybedtools.60okb10c.tmp has inconsistent naming convention for record:
# ...

# %%
group2_filtered = group2.intersect(group1, s=True, v=True)
group3_filtered = group3.intersect(group1, s=True, v=True).intersect(group2, s=True, v=True).intersect(
    group4, s=True, v=True)
group4_filtered = group4.intersect(group1, s=True, v=True).intersect(group2, s=True, v=True)
# Out:
# ***** WARNING: File /tmp/pybedtools.dw0tp997.tmp has inconsistent naming convention for record:
# chr1	280750	280760	.	120	-
#
# ***** WARNING: File /tmp/pybedtools.dw0tp997.tmp has inconsistent naming convention for record:
# chr1	280750	280760	.	120	-
#
# ***** WARNING: File /tmp/pybedtools.dw0tp997.tmp has inconsistent naming convention for record:
# chr1	280750	280760	.	120	-
#
# ***** WARNING: File /tmp/pybedtools.dw0tp997.tmp has inconsistent naming convention for record:
# chr1	280750	280760	.	120	-
#
# ***** WARNING: File /tmp/pybedtools.1hwqkfy4.tmp has inconsistent naming convention for record:
# chr1	280755	280763	.	52	-
#
# ***** WARNING: File /tmp/pybedtools.1hwqkfy4.tmp has inconsistent naming convention for record:
# chr1	280755	280763	.	52	-
#
# ***** WARNING: File /tmp/pybedtools.j3y0zuml.tmp has inconsistent naming convention for record:
# chr1	286745	286748	.	6	-
#
# ***** WARNING: File /tmp/pybedtools.j3y0zuml.tmp has inconsistent naming convention for record:
# ...

# %%
intersect_1_unmerged = rfiltered_merged30.intersect(group1,
    s=True,
    #wa=True,
    wao=True,
    #loj=True
    )
# Out:
# ***** WARNING: File /tmp/pybedtools.dw0tp997.tmp has inconsistent naming convention for record:
# chr1	280750	280760	.	120	-
#
# ***** WARNING: File /tmp/pybedtools.dw0tp997.tmp has inconsistent naming convention for record:
# chr1	280750	280760	.	120	-

# %%
def merge_peaks_temp(peaks, n):
    return peaks.sort().merge(d=n, s=True, c=[4, 5, 6, 13], o=['distinct', 'distinct', 'distinct', 'max'])

# %%
intersect_1 = merge_peaks_temp(intersect_1_unmerged, 0)

# %%
intersect_2_unmerged = rfiltered_merged30.intersect(group2_filtered,
    s=True,
    #wa=True,
    wao=True,
    #loj=True
    )
intersect_2 = merge_peaks_temp(intersect_2_unmerged, 0)
df_intersect2 = intersect_2.to_dataframe(names=['chrom', 'start', 'end', 'name', 'score', 'strand', 'overlap_g2'])
# Out:
# ***** WARNING: File /tmp/pybedtools.u_0zd1o4.tmp has inconsistent naming convention for record:
# chr1	808226	808232	.	35	-
#
# ***** WARNING: File /tmp/pybedtools.u_0zd1o4.tmp has inconsistent naming convention for record:
# chr1	808226	808232	.	35	-

# %%
intersect_3_unmerged = rfiltered_merged30.intersect(group3_filtered,
    s=True,
    #wa=True,
    wao=True,
    #loj=True
    )
intersect_3 = merge_peaks_temp(intersect_3_unmerged, 0)
df_intersect3 = intersect_3.to_dataframe(names=['chrom', 'start', 'end', 'name', 'score', 'strand', 'overlap_g3'])
# Out:
# ***** WARNING: File /tmp/pybedtools.8yu9akq3.tmp has inconsistent naming convention for record:
# chr1	280766	280772	.	5	-
#
# ***** WARNING: File /tmp/pybedtools.8yu9akq3.tmp has inconsistent naming convention for record:
# chr1	280766	280772	.	5	-

# %%
intersect_4_unmerged = rfiltered_merged30.intersect(group4_filtered,
    s=True,
    #wa=True,
    wao=True,
    #loj=True
    )
intersect_4 = merge_peaks_temp(intersect_4_unmerged, 0)
df_intersect4 = intersect_4.to_dataframe(names=['chrom', 'start', 'end', 'name', 'score', 'strand', 'overlap_g4'])
# Out:
# ***** WARNING: File /tmp/pybedtools.7k2cb7ec.tmp has inconsistent naming convention for record:
# chr1	286745	286748	.	6	-
#
# ***** WARNING: File /tmp/pybedtools.7k2cb7ec.tmp has inconsistent naming convention for record:
# chr1	286745	286748	.	6	-

# %%
df_intersect1 = intersect_1.to_dataframe(names=['chrom', 'start', 'end', 'name', 'score', 'strand', 'overlap_g1'])

# %%
df_out_rfiltered_merged30_inner = pd.merge(df_out_rfiltered_merged30, df_intersect1, on=[
    'chrom', 'start', 'end', 'name', 'score', 'strand'], how='inner')
df_out_rfiltered_merged30_inner = pd.merge(df_out_rfiltered_merged30_inner, df_intersect2, on=[
    'chrom', 'start', 'end', 'name', 'score', 'strand'], how='inner')
df_out_rfiltered_merged30_inner = pd.merge(df_out_rfiltered_merged30_inner, df_intersect3, on=[
    'chrom', 'start', 'end', 'name', 'score', 'strand'], how='inner')
df_out_rfiltered_merged30_inner = pd.merge(df_out_rfiltered_merged30_inner, df_intersect4, on=[
    'chrom', 'start', 'end', 'name', 'score', 'strand'], how='inner')

# %%
df_out_rfiltered_merged30_inner['len'] = df_out_rfiltered_merged30_inner.end - df_out_rfiltered_merged30_inner.start

# %%
df_out_rfiltered_merged30_inner['overlap_g1'] = df_out_rfiltered_merged30_inner['overlap_g1'] * 100 / df_out_rfiltered_merged30_inner.len
df_out_rfiltered_merged30_inner['overlap_g2'] = df_out_rfiltered_merged30_inner['overlap_g2'] * 100 / df_out_rfiltered_merged30_inner.len
df_out_rfiltered_merged30_inner['overlap_g3'] = df_out_rfiltered_merged30_inner['overlap_g3'] * 100 / df_out_rfiltered_merged30_inner.len
df_out_rfiltered_merged30_inner['overlap_g4'] = df_out_rfiltered_merged30_inner['overlap_g4'] * 100 / df_out_rfiltered_merged30_inner.len

# %%
df_out_rfiltered_merged30_inner.columns
# Out:
# Index(['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
#        'gene_id', 'gene_name',
#        'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-3-20181001-ju',
#        'tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-no-uv-1-20180829-ju',
#        'tardbp-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-a326p-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-q331k-egfp-hek293-3-20181001-ju',
# ...

# %%
df_out_rfiltered_merged30_inner.head()
# Out:
#         chrom   start     end name  score strand      region     biotype  \
# 0  GL000194.1   75522   75545    .   22.0      -      intron  "pre-mRNA"
# 1  GL000194.1   81461   81479    .   13.0      -      intron  "pre-mRNA"
# 2  GL000194.1   92228   92285    .   68.0      -      intron  "pre-mRNA"
# 3  GL000194.1   99578   99599    .   23.0      -      intron  "pre-mRNA"
# 4  GL000008.2  154464  154475    .  113.0      +  intergenic          ""
#
#                gene_id     gene_name  ...  \
# 0  "ENSG00000274847.1"  "AC145212.1"  ...
# 1  "ENSG00000274847.1"  "AC145212.1"  ...
# 2  "ENSG00000274847.1"  "AC145212.1"  ...
# 3  "ENSG00000274847.1"  "AC145212.1"  ...
# 4                  "."        "None"  ...
#
#    tardbp-316del346-egfp-293flp-l2-20171010-ju  \
# 0                                          0.0
# 1                                          0.0
# 2                                          0.0
# 3                                          3.0
# ...

# %%
df_out_rfiltered_merged30_inner['total_overlap'] = df_out_rfiltered_merged30_inner.overlap_g1 + df_out_rfiltered_merged30_inner.overlap_g2 + df_out_rfiltered_merged30_inner.overlap_g3 + df_out_rfiltered_merged30_inner.overlap_g4

# %%
df_out_rfiltered_merged30_inner['overlap_g1_pseudoc'] = df_out_rfiltered_merged30_inner.overlap_g1 + 1
df_out_rfiltered_merged30_inner['overlap_g2_pseudoc'] = df_out_rfiltered_merged30_inner.overlap_g2 + 1 
df_out_rfiltered_merged30_inner['overlap_g3_pseudoc'] = df_out_rfiltered_merged30_inner.overlap_g3 + 1
df_out_rfiltered_merged30_inner['overlap_g4_pseudoc'] = df_out_rfiltered_merged30_inner.overlap_g4 + 1

# %%
df_out_rfiltered_merged30_inner['length_groups'] = 'default'
df_out_rfiltered_merged30_inner.loc[df_out_rfiltered_merged30_inner.len <= 30, 'length_groups'] = '3len30'
df_out_rfiltered_merged30_inner.loc[(df_out_rfiltered_merged30_inner.len > 30) & (df_out_rfiltered_merged30_inner.len <= 60), 'length_groups'] = '2len30-60'
df_out_rfiltered_merged30_inner.loc[(df_out_rfiltered_merged30_inner.len > 60) & (df_out_rfiltered_merged30_inner.len <= 100), 'length_groups'] = '1len60-100'
df_out_rfiltered_merged30_inner.loc[df_out_rfiltered_merged30_inner.len > 100, 'length_groups'] = '0len100plus'

# %%
df_out_rfiltered_merged30_inner.length_groups.describe()
# Out:
# count        116332
# unique            4
# top       2len30-60
# freq          41128
# Name: length_groups, dtype: object

# %%
df_out_rfiltered_merged30_inner['total_overlap_bin'] = pd.qcut(df_out_rfiltered_merged30_inner['total_overlap'], 3, labels=['sparse', 'medium', 'dense'])

# %%
df_out_rfiltered_merged30_inner['g1plusg2byg4_ratio'] = (df_out_rfiltered_merged30_inner.overlap_g1_pseudoc + df_out_rfiltered_merged30_inner.overlap_g2_pseudoc) / df_out_rfiltered_merged30_inner.overlap_g4_pseudoc

# %%
del df_out_rfiltered_merged30_inner['total_overlap_bin']

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
df_out_rfiltered_merged30_inner.total_overlap.describe()
# Out:
# count    116332.000000
# mean         45.121566
# std          26.514989
# min           0.000000
# 25%          24.675325
# 50%          37.037037
# 75%          60.000000
# max         100.000000
# Name: total_overlap, dtype: float64

# %%
df_out_rfiltered_merged30_inner.groupby(['length_groups'], observed=False).total_overlap.describe()
# Out:
#                  count       mean        std       min        25%        50%  \
# length_groups
# 0len100plus    11850.0  20.447389  10.386551  1.039169  13.709677  18.238994
# 1len60-100     25056.0  30.597177  15.089638  6.060606  20.634921  26.562500
# 2len30-60      41128.0  40.080057  19.535335  3.030303  26.666667  35.294118
# 3len30         38298.0  67.672596  26.098560  0.000000  45.833333  66.666667
#
#                       75%         max
# length_groups
# 0len100plus     24.236506   98.701299
# 1len60-100      35.483871  100.000000
# 2len30-60       47.500000  100.000000
# 3len30         100.000000  100.000000

# %%
df_out_rfiltered_merged30_inner['overlap_group'] = df_out_rfiltered_merged30_inner.groupby(['length_groups'], observed=False)['total_overlap'].transform(
                     lambda x: pd.qcut(x, 3, labels=['sparse', 'medium', 'dense']))

# %%
df_out_rfiltered_merged30_inner.overlap_group.describe()
# Out:
# count     116332
# unique         3
# top       medium
# freq       38850
# Name: overlap_group, dtype: object

# %%
df_out_rfiltered_merged30_inner['g4byg1g2g3_ratio'] = df_out_rfiltered_merged30_inner.overlap_g4_pseudoc / (df_out_rfiltered_merged30_inner.overlap_g1_pseudoc + df_out_rfiltered_merged30_inner.overlap_g2_pseudoc + df_out_rfiltered_merged30_inner.overlap_g3_pseudoc)

# %%
df_out_rfiltered_merged30_inner.head()
# Out:
#         chrom   start     end name  score strand      region     biotype  \
# 0  GL000194.1   75522   75545    .   22.0      -      intron  "pre-mRNA"
# 1  GL000194.1   81461   81479    .   13.0      -      intron  "pre-mRNA"
# 2  GL000194.1   92228   92285    .   68.0      -      intron  "pre-mRNA"
# 3  GL000194.1   99578   99599    .   23.0      -      intron  "pre-mRNA"
# 4  GL000008.2  154464  154475    .  113.0      +  intergenic          ""
#
#                gene_id     gene_name  ...  overlap_g4  total_overlap  \
# 0  "ENSG00000274847.1"  "AC145212.1"  ...  100.000000     100.000000
# 1  "ENSG00000274847.1"  "AC145212.1"  ...   33.333333      55.555556
# 2  "ENSG00000274847.1"  "AC145212.1"  ...    0.000000      98.245614
# 3  "ENSG00000274847.1"  "AC145212.1"  ...    0.000000      47.619048
# 4                  "."        "None"  ...  100.000000     100.000000
#
#    overlap_g1_pseudoc  overlap_g2_pseudoc  overlap_g3_pseudoc  \
# ...

# %%
#top_g1plusg2byg4 = df_out_rfiltered_merged30_inner.groupby(['length_groups','overlap_group']).apply(lambda grp: grp.nlargest(3000, 'g1plusg2byg4_ratio'))

# %%
top_g1plusg2byg4_under100 = df_out_rfiltered_merged30_inner[df_out_rfiltered_merged30_inner.length_groups != '0len100plus'].groupby(['length_groups','overlap_group']).apply(lambda grp: grp.nlargest(3000, 'g1plusg2byg4_ratio'))
top_g1plusg2byg4_over100 = df_out_rfiltered_merged30_inner[df_out_rfiltered_merged30_inner.length_groups == '0len100plus'].groupby(['length_groups','overlap_group']).apply(lambda grp: grp.nlargest(1500, 'g1plusg2byg4_ratio'))

# %%
top_g1plusg2byg4 = pd.concat([top_g1plusg2byg4_under100, top_g1plusg2byg4_over100])

# %%
len(top_g1plusg2byg4_under100), len(top_g1plusg2byg4_over100), len(top_g1plusg2byg4_under100) + len(top_g1plusg2byg4_over100)
# Out:
# (27000, 4500, 31500)

# %%
top_g1plusg2byg4 = pd.concat([top_g1plusg2byg4_under100, top_g1plusg2byg4_over100])

# %%
top_g1plusg2byg4['ratio_group'] = 'UG'

# %%
top_g1plusg2byg4.head()
# Out:
#                                     chrom     start       end name  score  \
# length_groups overlap_group
# 1len60-100    sparse        12685   chr10  74936663  74936725    .   92.0
#                             73927    chr4  92611082  92611144    .   21.0
#                             15074   chr11   1405308   1405379    .  105.0
#                             64656   chr22  48754450  48754521    .   22.0
#                             114984  chr19  47759937  47760004    .  356.0
#
#                                    strand      region            biotype  \
# length_groups overlap_group
# 1len60-100    sparse        12685       +      intron         "pre-mRNA"
#                             73927       +      intron  "lncRNA,pre-mRNA"
#                             15074       +      intron         "pre-mRNA"
#                             64656       +      intron         "pre-mRNA"
#                             114984      +  intergenic                 ""
#
# ...

# %%
top_g1plusg2byg4 = top_g1plusg2byg4.reset_index(drop='True')

# %%
top_g1plusg2byg4.columns
# Out:
# Index(['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
#        'gene_id', 'gene_name',
#        'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-3-20181001-ju',
#        'tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-no-uv-1-20180829-ju',
#        'tardbp-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-a326p-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-q331k-egfp-hek293-3-20181001-ju',
# ...

# %%
df_1 = pd.merge(df_out_rfiltered_merged30_inner, top_g1plusg2byg4, 
        on=['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
       'gene_id', 'gene_name', 'tardbp-316del346-egfp-hek293-4-20181001-ju',
       #'tardbp-293flp-2-20181129-ju',
       'tardbp-316del346-egfp-hek293-3-20181001-ju',
       'tardbp-egfp-hek293-hd2-5-4-20180829-ju',
       'tardbp-a326p-egfp-hek293-4-20181001-ju',
       'tardbp-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
       'tardbp-g294a-egfp-hek293-4-20181001-ju',
       'tardbp-316del346-egfp-hek293-hd1-6-3-20180829-ju',
       'tardbp-320del414-egfp-hek293-hd1-6-3-20180829-ju',
       'tardbp-egfp-hek293-no-uv-1-20180829-ju',
       'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
       'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd2-5-4-20180829-ju',
       'tardbp-a326p-egfp-hek293-3-20181001-ju',
       'tardbp-g335a-egfp-hek293-3-20181001-ju',
       'tardbp-g294a-egfp-hek293-3-20181001-ju',
       'tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
       'tardbp-m337p-egfp-hek293-3-20181001-ju',
       'tardbp-q331k-egfp-hek293-4-20181001-ju',
       'tardbp-egfp-hek293-hd2-5-3-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju',
       'tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju',
       'tardbp-egfp-hek293-3-20181001-ju', #'tardbp-293flp-1-20181129-ju',
       'tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju',
       'tardbp-g335a-egfp-hek293-4-20181001-ju',
       'tardbp-316del346-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
       'tardbp-q331k-egfp-hek293-3-20181001-ju',
       'tardbp-egfp-hek293-hd1-6-4-20180829-ju',
       'tardbp-egfp-hek293-4-20181001-ju',
       'tardbp-m337p-egfp-hek293-4-20181001-ju',
       'tardbp-egfp-293flp-m2-20171010-ju',
       'tardbp-316del346-egfp-293flp-l1-20171010-ju',
       'tardbp-316del346-egfp-293flp-l2-20171010-ju',
       #'tardbp-293flp-2-20181129-ju', 
       'tardbp-egfp-293flp-l2-20171010-ju',
       'tardbp-316del346-egfp-293flp-m1-20171010-ju',
       'tardbp-egfp-293flp-l1-20171010-ju',
       'tardbp-316del346-egfp-293flp-m2-20171010-ju',
       'tardbp-egfp-293flp-m1-20171010-ju', #'tardbp-293flp-1-20181129-ju',
       'len', 'overlap_g1', 'overlap_g2', 'overlap_g3', 'overlap_g4',
       'total_overlap', 'overlap_g1_pseudoc', 'overlap_g2_pseudoc',
       'overlap_g3_pseudoc', 'overlap_g4_pseudoc', 'length_groups',
       'g1plusg2byg4_ratio', 'overlap_group', 'g4byg1g2g3_ratio',],
               how='left')

# %%
df_1.head()
# Out:
#         chrom   start     end name  score strand      region     biotype  \
# 0  GL000194.1   75522   75545    .   22.0      -      intron  "pre-mRNA"
# 1  GL000194.1   81461   81479    .   13.0      -      intron  "pre-mRNA"
# 2  GL000194.1   92228   92285    .   68.0      -      intron  "pre-mRNA"
# 3  GL000194.1   99578   99599    .   23.0      -      intron  "pre-mRNA"
# 4  GL000008.2  154464  154475    .  113.0      +  intergenic          ""
#
#                gene_id     gene_name  ...  total_overlap  overlap_g1_pseudoc  \
# 0  "ENSG00000274847.1"  "AC145212.1"  ...     100.000000            1.000000
# 1  "ENSG00000274847.1"  "AC145212.1"  ...      55.555556            1.000000
# 2  "ENSG00000274847.1"  "AC145212.1"  ...      98.245614           99.245614
# 3  "ENSG00000274847.1"  "AC145212.1"  ...      47.619048           48.619048
# 4                  "."        "None"  ...     100.000000            1.000000
#
# ...

# %%
len(df_1[df_1.ratio_group.isna()])
# Out:
# 84832

# %%
top_g4byg1g2g3_ratio_under100 = df_1[(df_1.ratio_group.isna()) & (df_1.length_groups != '0len100plus')].groupby(['length_groups','overlap_group']).apply(lambda grp: grp.nlargest(3000, 'g4byg1g2g3_ratio'))
top_g4byg1g2g3_ratio_over100 = df_1[(df_1.ratio_group.isna()) & (df_1.length_groups == '0len100plus')].groupby(['length_groups','overlap_group']).apply(lambda grp: grp.nlargest(1500, 'g4byg1g2g3_ratio'))

# %%
top_g4byg1g2g3_ratio = pd.concat([top_g4byg1g2g3_ratio_under100, top_g4byg1g2g3_ratio_over100])

# %%
top_g4byg1g2g3_ratio.ratio_group = 'AA'

# %%
top_g4byg1g2g3_ratio = top_g4byg1g2g3_ratio.reset_index(drop='True')

# %%
top_g4byg1g2g3_ratio.head()
# Out:
#    chrom      start        end name  score strand  region            biotype  \
# 0   chr1   17429892   17429954    .  188.0      -  intron         "pre-mRNA"
# 1   chr1  177032932  177032994    .   28.0      -  intron  "lncRNA,pre-mRNA"
# 2  chr12   12361647   12361709    .   73.0      +  intron         "pre-mRNA"
# 3   chr2  241426522  241426584    .   59.0      +  intron         "pre-mRNA"
# 4   chr5  142796184  142796246    .  207.0      +  intron         "pre-mRNA"
#
#                 gene_id   gene_name  ...  total_overlap  overlap_g1_pseudoc  \
# 0  "ENSG00000179051.13"      "RCC2"  ...      22.580645                 1.0
# 1  "ENSG00000152092.15"     "ASTN1"  ...      22.580645                 1.0
# 2  "ENSG00000165714.10"    "BORCS5"  ...      22.580645                 1.0
# 3  "ENSG00000006607.13"     "FARP2"  ...      22.580645                 1.0
# 4  "ENSG00000145819.15"  "ARHGAP26"  ...      22.580645                 1.0
#
# ...

# %%
top_g4byg1g2g3_ratio.columns
# Out:
# Index(['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
#        'gene_id', 'gene_name',
#        'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-3-20181001-ju',
#        'tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-no-uv-1-20180829-ju',
#        'tardbp-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-a326p-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-q331k-egfp-hek293-3-20181001-ju',
# ...

# %%
df_2 = pd.merge(df_1, top_g4byg1g2g3_ratio, 
        on=['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
       'gene_id', 'gene_name', 'tardbp-316del346-egfp-hek293-4-20181001-ju',
       #'tardbp-293flp-2-20181129-ju',
       'tardbp-316del346-egfp-hek293-3-20181001-ju',
       'tardbp-egfp-hek293-hd2-5-4-20180829-ju',
       'tardbp-a326p-egfp-hek293-4-20181001-ju',
       'tardbp-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
       'tardbp-g294a-egfp-hek293-4-20181001-ju',
       'tardbp-316del346-egfp-hek293-hd1-6-3-20180829-ju',
       'tardbp-320del414-egfp-hek293-hd1-6-3-20180829-ju',
       'tardbp-egfp-hek293-no-uv-1-20180829-ju',
       'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
       'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd2-5-4-20180829-ju',
       'tardbp-a326p-egfp-hek293-3-20181001-ju',
       'tardbp-g335a-egfp-hek293-3-20181001-ju',
       'tardbp-g294a-egfp-hek293-3-20181001-ju',
       'tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
       'tardbp-m337p-egfp-hek293-3-20181001-ju',
       'tardbp-q331k-egfp-hek293-4-20181001-ju',
       'tardbp-egfp-hek293-hd2-5-3-20180829-ju',
       'tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju',
       'tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju',
       'tardbp-egfp-hek293-3-20181001-ju', 
            #'tardbp-293flp-1-20181129-ju',
       'tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju',
       'tardbp-g335a-egfp-hek293-4-20181001-ju',
       'tardbp-316del346-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
       'tardbp-q331k-egfp-hek293-3-20181001-ju',
       'tardbp-egfp-hek293-hd1-6-4-20180829-ju',
       'tardbp-egfp-hek293-4-20181001-ju',
       'tardbp-m337p-egfp-hek293-4-20181001-ju',
       'tardbp-egfp-293flp-m2-20171010-ju',
       'tardbp-316del346-egfp-293flp-l1-20171010-ju',
       'tardbp-316del346-egfp-293flp-l2-20171010-ju',
       #'tardbp-293flp-2-20181129-ju', 
       'tardbp-egfp-293flp-l2-20171010-ju',
       'tardbp-316del346-egfp-293flp-m1-20171010-ju',
       'tardbp-egfp-293flp-l1-20171010-ju',
       'tardbp-316del346-egfp-293flp-m2-20171010-ju',
       'tardbp-egfp-293flp-m1-20171010-ju', 
            #'tardbp-293flp-1-20181129-ju',
       'len', 'overlap_g1', 'overlap_g2', 'overlap_g3', 'overlap_g4',
       'total_overlap', 'overlap_g1_pseudoc', 'overlap_g2_pseudoc',
       'overlap_g3_pseudoc', 'overlap_g4_pseudoc', 'length_groups',
       'g1plusg2byg4_ratio', 'overlap_group', 'g4byg1g2g3_ratio'],
               how='left')

# %%
df_2.head()
# Out:
#         chrom   start     end name  score strand      region     biotype  \
# 0  GL000194.1   75522   75545    .   22.0      -      intron  "pre-mRNA"
# 1  GL000194.1   81461   81479    .   13.0      -      intron  "pre-mRNA"
# 2  GL000194.1   92228   92285    .   68.0      -      intron  "pre-mRNA"
# 3  GL000194.1   99578   99599    .   23.0      -      intron  "pre-mRNA"
# 4  GL000008.2  154464  154475    .  113.0      +  intergenic          ""
#
#                gene_id     gene_name  ...  overlap_g1_pseudoc  \
# 0  "ENSG00000274847.1"  "AC145212.1"  ...            1.000000
# 1  "ENSG00000274847.1"  "AC145212.1"  ...            1.000000
# 2  "ENSG00000274847.1"  "AC145212.1"  ...           99.245614
# 3  "ENSG00000274847.1"  "AC145212.1"  ...           48.619048
# 4                  "."        "None"  ...            1.000000
#
#    overlap_g2_pseudoc  overlap_g3_pseudoc  overlap_g4_pseudoc  length_groups  \
# ...

# %%
df_2.loc[df_2.ratio_group_x.isna(),'ratio_group_x'] = df_2.ratio_group_y

# %%
df_2.loc[df_2.ratio_group_x.isna(),'ratio_group_x'] = 'UA'

# %%
df_2.groupby(['length_groups', 'overlap_group', 'ratio_group_x']).size()
# Out:
# length_groups  overlap_group  ratio_group_x
# 0len100plus    sparse         AA               1500
#                               UA                951
#                               UG               1500
#                medium         AA               1500
#                               UA                949
#                               UG               1500
#                dense          AA               1500
#                               UA                950
#                               UG               1500
# 1len60-100     sparse         AA               3000
#                               UA               2375
#                               UG               3000
#                medium         AA               3000
#                               UA               2352
#                               UG               3000
#                dense          AA               3000
#                               UA               2329
# ...

# %%
df_2.groupby(['ratio_group_x', 'length_groups', 'overlap_group',]).size()
# Out:
# ratio_group_x  length_groups  overlap_group
# AA             0len100plus    sparse           1500
#                               medium           1500
#                               dense            1500
#                1len60-100     sparse           3000
#                               medium           3000
#                               dense            3000
#                2len30-60      sparse           3000
#                               medium           3000
#                               dense            3000
#                3len30         sparse           3000
#                               medium           3000
#                               dense            3000
# UA             0len100plus    sparse            951
#                               medium            949
#                               dense             950
#                1len60-100     sparse           2375
#                               medium           2352
# ...

# %%
df_2.head()
# Out:
#         chrom   start     end name  score strand      region     biotype  \
# 0  GL000194.1   75522   75545    .   22.0      -      intron  "pre-mRNA"
# 1  GL000194.1   81461   81479    .   13.0      -      intron  "pre-mRNA"
# 2  GL000194.1   92228   92285    .   68.0      -      intron  "pre-mRNA"
# 3  GL000194.1   99578   99599    .   23.0      -      intron  "pre-mRNA"
# 4  GL000008.2  154464  154475    .  113.0      +  intergenic          ""
#
#                gene_id     gene_name  ...  overlap_g1_pseudoc  \
# 0  "ENSG00000274847.1"  "AC145212.1"  ...            1.000000
# 1  "ENSG00000274847.1"  "AC145212.1"  ...            1.000000
# 2  "ENSG00000274847.1"  "AC145212.1"  ...           99.245614
# 3  "ENSG00000274847.1"  "AC145212.1"  ...           48.619048
# 4                  "."        "None"  ...            1.000000
#
#    overlap_g2_pseudoc  overlap_g3_pseudoc  overlap_g4_pseudoc  length_groups  \
# ...

# %%
df_2.columns
# Out:
# Index(['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
#        'gene_id', 'gene_name',
#        'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-hd2-5-3-20180829-ju',
#        'tardbp-egfp-hek293-3-20181001-ju',
#        'tardbp-q331k-egfp-hek293-no-uv-1-20181001-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
#        'tardbp-316del346-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-no-uv-1-20180829-ju',
#        'tardbp-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-a326p-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-q331k-egfp-hek293-3-20181001-ju',
# ...

# %%
del df_2['ratio_group_y']

# %%
df_ug_100plus_dense = df_2[(df_2.ratio_group_x == 'UG') & (df_2.length_groups == '0len100plus') & (df_2.overlap_group == 'dense')]

# %%
df_ug_100plus_medium = df_2[(df_2.ratio_group_x == 'UG') & (df_2.length_groups == '0len100plus') & (df_2.overlap_group == 'medium')]

# %%
df_ua_0len100plus_dense = df_2[(df_2.ratio_group_x == 'UA') & (df_2.length_groups == '0len100plus') & (df_2.overlap_group == 'dense')]

# %%
df_ug_3len30_dense = df_2[(df_2.ratio_group_x == 'UG') & (df_2.length_groups == '3len30') & (df_2.overlap_group == 'dense')]

# %%
df_ug_len60to100_dense = df_2[(df_2.ratio_group_x == 'UG') & (df_2.length_groups == '1len60-100') & (df_2.overlap_group == 'dense')]

# %%
df_ug_len30to60_dense = df_2[(df_2.ratio_group_x == 'UG') & (df_2.length_groups == '2len30-60') & (df_2.overlap_group == 'dense')]

# %%
row_order = pd.read_excel('/home/aram/Dropbox (UCL-MN Team)/aram/martina_tdp43/reanalysis_all_samples/row_order.xlsx')

# %%
row_order

# %%
df_2_all_samples_rfiltered = pd.read_csv('/home/aram/Dropbox (The Francis Crick)/ucl/aram/martina_tdp43/reanalysis_all_samples/df_2_all_samples_rfiltered_unnormalised.tsv', sep='\t')

# %%
df_2_all_samples_rfiltered.head()
# Out:
#         chrom   start     end name  score strand      region     biotype  \
# 0  GL000194.1   75522   75545    .   22.0      -      intron  "pre-mRNA"
# 1  GL000194.1   81461   81479    .   13.0      -      intron  "pre-mRNA"
# 2  GL000194.1   92228   92285    .   68.0      -      intron  "pre-mRNA"
# 3  GL000194.1   99578   99599    .   23.0      -      intron  "pre-mRNA"
# 4  GL000008.2  154464  154475    .  113.0      +  intergenic          ""
#
#                gene_id     gene_name  ...  total_overlap  overlap_g1_pseudoc  \
# 0  "ENSG00000274847.1"  "AC145212.1"  ...     100.000000            1.000000
# 1  "ENSG00000274847.1"  "AC145212.1"  ...      55.555556            1.000000
# 2  "ENSG00000274847.1"  "AC145212.1"  ...      98.245614           99.245614
# 3  "ENSG00000274847.1"  "AC145212.1"  ...      47.619048           48.619048
# 4                  "."        "None"  ...     100.000000            1.000000
#
# ...

# %%
df_2_all_samples_rfiltered.columns
# Out:
# Index(['chrom', 'start', 'end', 'name', 'score', 'strand', 'region', 'biotype',
#        'gene_id', 'gene_name', 'tardbp-316del346-egfp-hek293-4-20181001-ju',
#        'tardbp-316del346-egfp-hek293-3-20181001-ju',
#        'tardbp-egfp-hek293-hd2-5-4-20180829-ju',
#        'tardbp-a326p-egfp-hek293-4-20181001-ju',
#        'tardbp-egfp-hek293-hd1-6-on-bead-rt-1-20180829-ju',
#        'tardbp-g294a-egfp-hek293-4-20181001-ju',
#        'tardbp-316del346-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-320del414-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-egfp-hek293-no-uv-1-20180829-ju',
#        'tardbp-egfp-hek293-hd2-5-on-bead-rt-1-20180829-ju',
#        'tardbp-egfp-hek293-hd1-6-3-20180829-ju',
#        'tardbp-316del346-egfp-hek293-hd1-6-4-20180829-ju',
#        'tardbp-316del346-egfp-hek293-hd2-5-4-20180829-ju',
#        'tardbp-a326p-egfp-hek293-3-20181001-ju',
#        'tardbp-g335a-egfp-hek293-3-20181001-ju',
#        'tardbp-g294a-egfp-hek293-3-20181001-ju',
# ...

# %%
df_2_all_samples_rfiltered[['chrom', 'start', 'end', 'name', 'score', 'strand', 
                            'length_groups', 'overlap_group', 'ratio_group_x']]

# %%
df_2_all_samples_rfiltered[['chrom', 'start', 'end', 'name', 'score', 'strand', 
                            'length_groups', 'overlap_group', 'ratio_group_x']].to_csv(
    'tardbp_reference_binding_sites.bed', sep='\t', index=None, header=None)

# %%
df_out_rfiltered_merged30_inner.groupby(['length_groups'], observed=False).total_overlap.describe()
# Out:
#                  count       mean        std       min        25%        50%  \
# length_groups
# 0len100plus    11850.0  20.447389  10.386551  1.039169  13.709677  18.238994
# 1len60-100     25056.0  30.597177  15.089638  6.060606  20.634921  26.562500
# 2len30-60      41128.0  40.080057  19.535335  3.030303  26.666667  35.294118
# 3len30         38298.0  67.672596  26.098560  0.000000  45.833333  66.666667
#
#                       75%         max
# length_groups
# 0len100plus     24.236506   98.701299
# 1len60-100      35.483871  100.000000
# 2len30-60       47.500000  100.000000
# 3len30         100.000000  100.000000

# %%
df_2_all_samples_rfiltered.groupby(['length_groups'], observed=False).total_overlap.describe()
# Out:
#                  count       mean        std       min        25%        50%  \
# length_groups
# 0len100plus    11850.0  20.447389  10.386551  1.039169  13.709677  18.238994
# 1len60-100     25056.0  30.597177  15.089638  6.060606  20.634921  26.562500
# 2len30-60      41128.0  40.080057  19.535335  3.030303  26.666667  35.294118
# 3len30         38298.0  67.672596  26.098560  0.000000  45.833333  66.666667
#
#                       75%         max
# length_groups
# 0len100plus     24.236506   98.701299
# 1len60-100      35.483871  100.000000
# 2len30-60       47.500000  100.000000
# 3len30         100.000000  100.000000

# %%
df_2_all_samples_rfiltered[['chrom', 'start', 'end', 'name', 'score', 'strand', 
                            'length_groups', 'overlap_group', 'ratio_group_x']].to_csv(
    'tardbp_reference_binding_sites_reproduced.bed', sep='\t', index=None, header=None)
